# %%
#qiskit version 1.4.3
#qiskit-algorithms version 0.3.1 
#qiskit Aer version 0.17.1
#PySCF version 2.9.0
#qiskit-nature 0.7.2
#numpy version latest
#ase version latest
#qBraid 0.10.0
#amazon-bracket-sdk version 1.96.1 
#API key = 2j0oioxb0opd7cv6cf06ka6eszwgbf

# %%
#%pip install qiskit_qasm3_import
from qiskit import QuantumCircuit
from qiskit import transpile
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit.library import TwoLocal
from qiskit.primitives import StatevectorEstimator 

from qiskit_nature.second_q.hamiltonians import LatticeModel
from qiskit_nature.second_q.hamiltonians import FermiHubbardModel
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.operators import FermionicOp
from qiskit_nature.second_q.hamiltonians.lattices import Lattice, BoundaryCondition
from qiskit.circuit.library import TwoLocal

import qiskit_nature
from qiskit_algorithms.minimum_eigensolvers import NumPyMinimumEigensolver, VQE
from qiskit_nature.second_q.transformers import FreezeCoreTransformer, ActiveSpaceTransformer
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock, PUCCD, SUCCD
from qiskit_algorithms.optimizers import SPSA, SLSQP, COBYLA 

qiskit_nature.settings.use_pauli_sum_op = False  # pylint: disable=undefined-variable
# pylint: enable=line-too-long
from qiskit_nature.second_q.drivers import PySCFDriver
import matplotlib.pyplot as plt
import numpy as numpy
from qiskit.circuit.library import EfficientSU2, RealAmplitudes 
from qiskit_aer.primitives import Estimator

from qiskit_aer.noise import NoiseModel
from qiskit_aer.primitives import Estimator as AerEstimator
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit.qasm3 import loads
from qiskit import qasm2

from pyscf import gto, scf, cc
from pyscf.pbc import gto
from pyscf.pbc.gto.cell import fromfile

import ase
from ase.io import read
from ase.neighborlist import NeighborList
import time

import qbraid
import qbraid.runtime
from qbraid.visualization import plot_histogram
#from qiskit_ibm_runtime import QiskitRuntimeService 
#from qiskit_ibm_runtime import Estimator as IBMEstimator
#from qiskit_braket_provider import BraketEstimator, BraketProvider
#from qbraid.runtime import QbraidProvider 
#from qbraid.runtime.native import get_device, list_devices 
from qiskit.primitives import BackendEstimatorV2
from collections import Counter

# %%
#authenticate with qBraid, pull credits
import os 
os.environ["QBRAID_API_KEY"] = "2j0oioxb0opd7cv6cf06ka6eszwgbf"
from qbraid.runtime import QbraidProvider 
provider = QbraidProvider() 

devices = provider.get_devices()
print("qBraid available devices:") 
for device in devices: 
    print(device)
#Choose available device from the ones listed
    
#device = provider.get_device("qbraid_qir_simulator")
#device = provider.get_device("aws_sv1")
#device = provider.get_device("aws_dm1") 
device = provider.get_device("iqm_emerald")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 import os
#       3 os.environ["QBRAID_API_KEY"] = "2j0oioxb0opd7cv6cf06ka6eszwgbf"
# ----> 4 from qbraid.runtime import QbraidProvider
#       5 provider = QbraidProvider()
#       7 devices = provider.get_devices()
#
# File ~/.qbraid/environments/cmjt/pyenv/lib/python3.11/site-packages/qbraid/runtime/__init__.py:209, in __getattr__(name)
#     206     return module
#     208 if name in objects:
# --> 209     module = importlib.import_module(f".{mod_name}", __name__)
#     210     obj = getattr(module, name)
#     211     globals()[name] = obj
#
# File /opt/conda/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.qbraid/environments/cmjt/pyenv/lib/python3.11/site-packages/qbraid/runtime/native/__init__.py:47
#       1 # Copyright 2025 qBraid
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """
#      16 Module providing interface for submitting and managing
#      17 quantum jobs through (native) qBraid APIs.
#    (...)     45
#      46 """
# ---> 47 from qbraid_core import QbraidClient, QbraidSession, Session
#      48 from qbraid_core.services.quantum.runner import QirRunner
#      50 from .device import QbraidDevice
#
# ImportError: cannot import name 'QbraidClient' from 'qbraid_core' (/home/jovyan/.qbraid/environments/cmjt/pyenv/lib/python3.11/site-packages/qbraid_core/__init__.py)

# %%
###
#
###

#1. Use ase to load atomic data (.xyz)

start = time.time()
class DummyUnit:
    def __init__(self, value):
        self.value = value 
        
atoms = read("9007660.xyz")
print(atoms.cell)

supercell = atoms.repeat((1,1,2))
print("Atoms in supercell:", len(supercell))

cell_center = numpy.mean(supercell.get_positions(), axis=0)
radius = 7.0 

positions = supercell.get_positions()
symbols = [a.symbol for a in supercell]

dists = numpy.linalg.norm(positions - cell_center, axis=1)
selected_idx = numpy.where(dists <= radius)[0]

cluster_symbols = [symbols[i] for i in selected_idx]
cluster_positions = positions[selected_idx]

print("Selected atoms count:", len(cluster_symbols))

cluster_atoms = []
for s, pos in zip(cluster_symbols, cluster_positions):
    cluster_atoms.append(f"{s} {pos[0]: .8f} {pos[1]: .8f} {pos[2]: .8f}")

molecule_str = "\n".join(cluster_atoms)
#print("Molecule string (first lines):")


driver = PySCFDriver(atom=molecule_str, unit=DummyUnit("Angstrom"), basis='lanl2dz')
freeze_core = FreezeCoreTransformer()
es_problem = driver.run()

es_problem_fc = freeze_core.transform(es_problem) 
print("Core Orbitals is frozen!")
active_space = ActiveSpaceTransformer(
    num_electrons=4,#4 
    num_spatial_orbitals=3#3 
    )
es_problem_active = active_space.transform(es_problem_fc)

print("Number of spatial orbitals from driver:", es_problem.num_spatial_orbitals)
print("Number of electrons {total}:", es_problem.num_particles)

#4. Turn into hamiltonian 
second_q_op = es_problem_active.hamiltonian.second_q_op()
#print("Second quantized operator:", second_q_op)

print("Number of frozen spatial orbitals from driver:", es_problem_fc.num_spatial_orbitals)
print("Number of frozen electrons {total}:", es_problem_fc.num_particles)
#5. Map to qubits 
mapper = ParityMapper()
qubit_op = mapper.map(second_q_op) 
num_qubits = qubit_op.num_qubits

print("Mapped to qubits!")

num_spin_orbitals = es_problem_active.num_spatial_orbitals * 2
num_particles = es_problem_active.num_particles

print("num_spin_orbitals:", num_spin_orbitals)
print("num_particles (alpha,beta):", num_particles)


initial_state = HartreeFock(num_spatial_orbitals=es_problem_active.num_spatial_orbitals,
               num_particles=es_problem_active.num_particles,qubit_mapper = mapper) 
#6. Set up and solve with VQE 
#ansatz = SUCCD(es_problem_active.num_spatial_orbitals,
#               es_problem_active.num_particles,
#               mapper,
#               initial_state=initial_state)

ansatz = RealAmplitudes(
    num_qubits=num_qubits,   # number of qubits from mapping
#    rotation_blocks=["ry", "rz"],   # can also try just "ry" or ["rx","ry","rz"]
#    entanglement_blocks="cx",       # CNOT entanglement
    entanglement="full",            # options: "linear", "circular", "full"
    reps=3,                         # number of alternating layers
    insert_barriers=True
) 

#ansatz.initial_state.compose(ansatz)
optimizer = SPSA(maxiter=500) 

estimator = Estimator()
#estimator = AerEstimator()
#estimator = IBMEstimator()
#service = QiskitRuntimeServices()
#estimator = BackendEstimatorV2(device)
print("\nDevice Name:", device.id)
#print("Device Type:", device.type)
print("VQE Starting!")

#vqe = VQE(ansatz=ansatz, optimizer=optimizer, estimator=estimator)
#result = vqe.compute_minimum_eigenvalue(qubit_op)
end = time.time()
#elapsed = end - start
#Exact result for comparison
#exact_solver = NumPyMinimumEigensolver()
#exact_result = exact_solver.compute_minimum_eigenvalue(qubit_op)

#print("VQE ground state energy:", result.eigenvalue.real)
#print("Exact ground state energy:", exact_result.eigenvalue.real)
#print("Number of qubits:", ansatz.num_qubits)
#print(f"VQE calculation took {elapsed:.2f} seconds")

###SUBMITTING QASM CIRCUIT TO JOBS

#qc = load("circuit.qasm")
with open("circuit.qasm") as f:
    qasm_str = f.read()

qc = loads(qasm_str)
#print(qc)
all_counts = []

qc_t = transpile(qc, optimization_level=3)
print("Circuit transpiled, heaing to calc")
shots = 1000
n_runs = 5
for i in range(n_runs):
    job = device.run(qc_t, shots=shots)
#print("\n Sim Test Starting: ")
#theta_sample = numpy.random.rand(len(ansatz.parameters))
#print("\n theta sample thingy made ")
#bound_circuit = ansatz.assign_parameters(dict(zip(ansatz.parameters, theta_sample)))
#print("\n binded parameters to the ansatz")
#transpiled_circuit = transpile(bound_circuit, basis_gates=['rx', 'ry', 'cz']) 
#print("\ntranspile the circuit")

#job = device.run([transpiled_circuit], shots=100)[0]
    sim_result = job.result()
    counts = sim_result.data.get_counts() 
    all_counts.append(counts)

#tag all observed bitstrings 
#bitstrings = sorted({bit for counts in all_counts for bit in counts})
#tag top bitstrings
total_counter = Counter()
for counts in all_counts:
    total_counter.update(counts)
top_n = 10
most_common = total_counter.most_common(top_n)
top_bits = [bit for bit, _ in most_common]

#compute probabilities per bitstring per run
means = []
stds = []
#probs_per_bitstring = {bit: [] for bit in top_bits}

for bits in top_bits:
    probs = []
    for counts in all_counts:
        total_shots = sum(counts.values())
        prob = counts.get(bit, 0) / total_shots
        probs.append(prob)
        #probs_per_bitstring[bit].append(prob)
    means.append(numpy.mean(probs))
    stds.append(numpy.std(probs))
#compute mean and standard deviation (shot noise)
#means = [numpy.mean(probs_per_bitstring[bit]) for bit in top_bits]
#stdevs = [numpy.std(probs_per_bitstring[bit]) for bit in top_bits]

#plotting
plt.figure(figsize=(10,5))
plt.bar(top_bits, means, yerr=stdevs, capsize=5)
plt.xlabel("Bitstring (0th qubit on right")
plt.ylabel("Probability")
plt.title(f"Top {top_n} most common bitstrings with shot noise ({shots} shots, {n_runs} runs)")
plt.show()
#plot_histogram(all_counts, legend=[f'Run {_+1}' for _ in range(5)])
#plt.show()
#braket_job = device.run(vqe, shots=100) 
#braket_job.status()

#sim_result = braket_job.result()
#counts = sim_result.data.get_counts()
#print(counts)
#sim_result
# Out:
# Cell([[3.161, 0.0, 0.0], [-1.5805, 2.7379, 0.0], [0.0, 0.0, 6.1475]])
# Atoms in supercell: 14
# Selected atoms count: 14
# Core Orbitals is frozen!
# Number of spatial orbitals from driver: 140
# Number of electrons {total}: (138, 138)
# Number of frozen spatial orbitals from driver: 44
# Number of frozen electrons {total}: (42, 42)
# Mapped to qubits!
# num_spin_orbitals: 6
# num_particles (alpha,beta): (2, 2)
#
# Device Name: iqm_emerald
# VQE Starting!
# Circuit transpiled, heaing to calc
